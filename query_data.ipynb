# %%
import yaml
import pandas as pd

# %%
with open("./order.yml") as f:
    draft_order = yaml.load(f, yaml.Loader)

# %%
draft_order
# Out:
# {'Team1': {'ban': [1, 3, 9, 11, 13, 19, 21], 'pick': [5, 8, 16, 17, 23]},
#  'Team2': {'ban': [2, 4, 10, 12, 14, 20, 22], 'pick': [6, 7, 15, 18, 24]}}

# %%
df = pd.read_csv("./data/matches.csv")

# %%
df
# Out:
#                       match_title            match_id         team1_name  \
# 0    The International 11 Playoff  Game 1: 6832008209        Team Secret
# 1    The International 11 Playoff  Game 2: 6832140410        Team Secret
# 2    The International 11 Playoff  Game 3: 6832287527        Team Secret
# 3    The International 11 Playoff  Game 1: 6831574509        Team Liquid
# 4    The International 11 Playoff  Game 2: 6831640716        Team Liquid
# ..                            ...                 ...                ...
# 226                           NaN  Game 2: 6806112746        Team Liquid
# 227                           NaN  Game 1: 6806047579            PSG.LGD
# 228                           NaN  Game 2: 6806097974            PSG.LGD
# 229                           NaN  Game 1: 6806047539  Shopify Rebellion
# 230                           NaN  Game 2: 6806094304  Shopify Rebellion
#
#          team2_name   team1_side   team2_side team1_pick team2_pick   winner  \
# 0    Tundra Esports  The Radiant     The Dire   1st Pick        NaN   Tundra
# 1    Tundra Esports  The Radiant     The Dire        NaN   1st Pick   Tundra
# 2    Tundra Esports     The Dire  The Radiant   1st Pick        NaN   Tundra
# 3       Team Secret     The Dire  The Radiant   1st Pick        NaN   Secret
# 4       Team Secret     The Dire  The Radiant        NaN   1st Pick   Liquid
# ..              ...          ...          ...        ...        ...      ...
# 226         Knights     The Dire  The Radiant   1st Pick        NaN  Knights
# 227         Ukumari     The Dire  The Radiant   1st Pick        NaN  PSG.LGD
# 228         Ukumari     The Dire  The Radiant        NaN   1st Pick      Uku
# 229   Thiuth Gaming  The Radiant     The Dire        NaN   1st Pick       SR
# 230   Thiuth Gaming     The Dire  The Radiant   1st Pick        NaN       SR
#
#                   1  ...         15             16            17           18  \
# 0              Doom  ...   Hoodwink         Enigma          Lich   Naga Siren
# 1      Nyx Assassin  ...       Chen   Chaos Knight       Phoenix  Bristleback
# 2              Doom  ...  Pangolier       Silencer    Naga Siren  Beastmaster
# 3           Leshrac  ...     Sniper    Lifestealer          Lich  Beastmaster
# 4    Crystal Maiden  ...     Jakiro   Nyx Assassin  Primal Beast         Tiny
# ..              ...  ...        ...            ...           ...          ...
# 226    Nyx Assassin  ...       Tiny  Queen of Pain     Disruptor  Broodmother
# 227        Batrider  ...  Clockwerk         Dazzle          Zeus       Kunkka
# 228    Primal Beast  ...    Leshrac           Zeus     Clockwerk       Visage
# 229          Enigma  ...     Mirana           Bane        Magnus  Drow Ranger
# 230          Enigma  ...  Disruptor    Broodmother        Rubick        Slark
#
#                 19             20             21             22  \
# 0            Lycan    Bloodseeker  Night Stalker    Drow Ranger
# 1        Pangolier          Viper       Batrider       Hoodwink
# 2    Troll Warlord  Shadow Shaman    Lifestealer      Clockwerk
# 3       Gyrocopter           Mars    Bloodseeker           Tiny
# 4       Lone Druid      Morphling     Naga Siren       Batrider
# ..             ...            ...            ...            ...
# 226           Puck           Luna   Ember Spirit    Monkey King
# 227    Beastmaster     Juggernaut            Axe  Faceless Void
# 228     Naga Siren    Beastmaster     Lone Druid     Venomancer
# 229          Viper    Bloodseeker     Venomancer    Monkey King
# 230     Tidehunter    Bloodseeker      Pangolier        Leshrac
#
#                    23             24
# 0               Pudge     Tidehunter
# 1          Arc Warden      Morphling
# 2        Ember Spirit         Medusa
# 3        Primal Beast      Morphling
# 4       Queen of Pain         Sniper
# ..                ...            ...
# 226  Legion Commander           Ursa
# 227       Terrorblade     Brewmaster
# 228          Snapfire  Faceless Void
# 229        Juggernaut    Beastmaster
# 230       Terrorblade           Mars
#
# [231 rows x 33 columns]

# %%
def get_draft_ban(row, team):
    team_number = row.index[row == team][0].split('_')[0]
    first_pick = bool(row[team_number+'_pick'])
    side = row[team_number+'_side']
    
    if first_pick:
        order = draft_order['Team1']
    else:
        order = draft_order['Team2']
        
    bans = row[[str(i) for i in order['ban']]]
    picks = row[[str(i) for i in order['pick']]]
    
    return {
        'team': team, 'first_pick': first_pick, 'side': side, 'bans': list(bans), 'picks': list(picks)
    }

# %%
row = df.loc[1]
row
# Out:
# match_title    The International 11 Playoff
# match_id                 Game 2: 6832140410
# team1_name                      Team Secret
# team2_name                   Tundra Esports
# team1_side                      The Radiant
# team2_side                         The Dire
# team1_pick                              NaN
# team2_pick                         1st Pick
# winner                               Tundra
# 1                              Nyx Assassin
# 2                               Broodmother
# 3                               Monkey King
# 4                                      Doom
# 5                                     Marci
# 6                                   Leshrac
# 7                                      Tusk
# 8                                    Visage
# 9                                    Sniper
# 10                               Naga Siren
# 11                              Bloodseeker
# 12                                   Mirana
# 13                              Beastmaster
# 14                                     Luna
# 15                                     Chen
# 16                             Chaos Knight
# 17                                  Phoenix
# 18                              Bristleback
# 19                                Pangolier
# 20                                    Viper
# 21                                 Batrider
# 22                                 Hoodwink
# 23                               Arc Warden
# 24                                Morphling
# Name: 1, dtype: object

# %%
team = 'Tundra Esports'

# %%
get_draft_ban(row, team)
# Out:
# {'team': 'Tundra Esports',
#  'first_pick': True,
#  'side': 'The Dire',
#  'bans': ['Nyx Assassin',
#   'Monkey King',
#   'Sniper',
#   'Bloodseeker',
#   'Beastmaster',
#   'Pangolier',
#   'Batrider'],
#  'picks': ['Marci', 'Visage', 'Chaos Knight', 'Phoenix', 'Arc Warden']}
